# %%
def validate_email(value):
        """Check to see if an email entity was actually picked up by duckling."""
        if re.match(r"(^[a-zA-Z0-9_.+-]+@[a-zA-Z-]+\.[a-zA-Z-.]+$)", value):
            print("inside validate email")   
            # entity was picked up, validate slot
        else:
            # no entity was picked up, we want to ask again
            print("inside invalidate email")

# %%
import re
validate_email("arbaz@gmail.gm")
# Out:
# inside validate email

# %%
file = open("name_lookup.txt","a")

# %%
file1
# Out:
# <_io.TextIOWrapper name='name_lookup.txt' mode='a' encoding='UTF-8'>

# %%
print(file1.readline())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-7-e58e4bdf2443> in <module>
# ----> 1 print(file1.readline())
#
# UnsupportedOperation: not readable

# %%
with open("name_lookup.txt") as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content]

# %%
content
# Out:
# []

# %%
lines = [line.rstrip('\n') for line in open('name_lookup.txt')]

# %%
lines
# Out:
# []

# %%
with open("name_lookup.txt", "r") as ins:
    array = []
    for line in ins:
        array.append(line)

# %%
array
# Out:
# []

# %%
lines = tuple(open("name_lookup", 'r'))

# %%
lines
# Out:
# ('aakash\n',
#  'ramdin verma\n',
#  'sharat chandran\n',
#  'birender mandal\n',
#  'amit\n',
#  'kushal\n',
#  'kasid\n',
#  'shiv prakash\n',
#  'vikram singh\n',
#  'sanjay\n',
#  'abhi\n',
#  'ram\n',
#  'khadak singh\n',
#  'gurmit singh\n',
#  'chanderpal\n',
#  'aman\n',
#  'khursid\n',
#  'rajeev\n',
#  'durgesh\n',
#  'nahar singh\n',
#  'ram kumar\n',
#  'arbaz\n',
#  'aditya\n',
#  'vaishali\n',
#  'abhay\n',
#  'waseef\n',
#  'sunder paal\n',
#  'maansingh aswal\n',
#  'rohit\n',
#  'rohit\n',
#  'sparsh\n',
#  'santosh\n',
#  'santosh\n',
#  'punit khandelwal\n',
#  'dinesh\n',
#  'gulshan\n',
#  'arvind kumar yadav\n',
#  'nausad\n',
#  'gurmit singh\n',
#  'md. afsar\n',
#  'shiv shakti singh\n',
#  'moti lal\n',
#  'kausal kumar\n',
#  'rohit\n',
#  'rohit\n',
#  'mohabbat ali\n',
#  'raj kumar\n',
#  'jaswant singh\n',
#  'sevak\n',
#  'chotelal\n',
#  'amit\n',
#  'rupesh\n',
#  'midda\n',
#  'dharam singh\n',
#  'manoj yadav\n',
#  'ram singh\n',
# ...

# %%
name_line = ""
for i in lines:
    i.replace("\n","")
    print(i)
    name_line +=i
# Out:
# aakash
#
# ramdin verma
#
# sharat chandran
#
# birender mandal
#
# amit
#
# kushal
#
# kasid
#
# shiv prakash
#
# vikram singh
#
# sanjay
#
# abhi
#
# ram
#
# khadak singh
#
# gurmit singh
#
# chanderpal
#
# aman
#
# khursid
#
# rajeev
#
# durgesh
#
# nahar singh
#
# ram kumar
#
# arbaz
#
# aditya
#
# vaishali
#
# abhay
#
# waseef
#
# sunder paal
#
# maansingh aswal
#
# rohit
#
# rohit
#
# sparsh
#
# santosh
#
# santosh
#
# punit khandelwal
#
# dinesh
#
# gulshan
#
# arvind kumar yadav
#
# nausad
#
# gurmit singh
#
# md. afsar
#
# shiv shakti singh
#
# moti lal
#
# kausal kumar
#
# rohit
#
# rohit
#
# mohabbat ali
#
# raj kumar
#
# jaswant singh
#
# sevak
#
# chotelal
#
# amit
#
# rupesh
#
# midda
#
# dharam singh
#
# manoj yadav
#
# ram singh
#
# preetam kumar
#
# ram kumar
#
# sarain
#
# pankaj kumar
#
# sheak shakir
#
# riyasat ali
#
# vinit katariya
#
# sumit
#
# arindra
#
# kali charan
#
# badshya khan
#
# vikash
#
# devinder chadda
#
# aman
#
# mohan singh
#
# hemant
#
# ...

# %%
name_line = name_line.split("\n")

# %%
len(lines)
# Out:
# 30219

# %%
name_line
# Out:
# ['aakash',
#  'ramdin verma',
#  'sharat chandran',
#  'birender mandal',
#  'amit',
#  'kushal',
#  'kasid',
#  'shiv prakash',
#  'vikram singh',
#  'sanjay',
#  'abhi',
#  'ram',
#  'khadak singh',
#  'gurmit singh',
#  'chanderpal',
#  'aman',
#  'khursid',
#  'rajeev',
#  'durgesh',
#  'nahar singh',
#  'ram kumar',
#  'arbaz',
#  'aditya',
#  'vaishali',
#  'abhay',
#  'waseef',
#  'sunder paal',
#  'maansingh aswal',
#  'rohit',
#  'rohit',
#  'sparsh',
#  'santosh',
#  'santosh',
#  'punit khandelwal',
#  'dinesh',
#  'gulshan',
#  'arvind kumar yadav',
#  'nausad',
#  'gurmit singh',
#  'md. afsar',
#  'shiv shakti singh',
#  'moti lal',
#  'kausal kumar',
#  'rohit',
#  'rohit',
#  'mohabbat ali',
#  'raj kumar',
#  'jaswant singh',
#  'sevak',
#  'chotelal',
#  'amit',
#  'rupesh',
#  'midda',
#  'dharam singh',
#  'manoj yadav',
#  'ram singh',
#  'preetam kumar',
#  'ram kumar',
#  'sarain',
#  'pankaj kumar',
#  'sheak shakir',
#  'riyasat ali',
#  'vinit katariya',
# ...

# %%
l = name_line

# %%
for i in l:
    if len(i.split())>1:
        print(i)
        print(len(i.split()))
        name_line.remove(i)

# %%
len(name_line)
# Out:
# 16435

# %%
name_line
# Out:
# ['aakash',
#  'amit',
#  'kushal',
#  'kasid',
#  'sanjay',
#  'abhi',
#  'ram',
#  'chanderpal',
#  'aman',
#  'khursid',
#  'rajeev',
#  'durgesh',
#  'arbaz',
#  'aditya',
#  'vaishali',
#  'abhay',
#  'waseef',
#  'rohit',
#  'rohit',
#  'sparsh',
#  'santosh',
#  'santosh',
#  'dinesh',
#  'gulshan',
#  'nausad',
#  'rohit',
#  'rohit',
#  'sevak',
#  'chotelal',
#  'amit',
#  'rupesh',
#  'midda',
#  'sarain',
#  'sumit',
#  'arindra',
#  'vikash',
#  'aman',
#  'hemant',
#  'shivam',
#  'aakash',
#  'chandesh',
#  'irfan',
#  'azaruddin',
#  'manoj',
#  'pawan',
#  'sandeep',
#  'parvesh',
#  'yogita',
#  'rajender',
#  'suraj',
#  'rizwan',
#  'sandeep',
#  'deepak',
#  'rahul',
#  'abhishekh',
#  'sanjay',
#  'ankit',
#  'amit',
#  'arjun',
#  'raju',
#  'santlal',
#  'sumit',
#  'tammanne',
#  'ajay',
#  'silender',
#  'deepak',
#  'akhilesh',
#  'nitin',
#  'rahul',
#  'adnan',
#  'vijay',
#  'yogesh',
#  'kabir',
#  'sarvesh',
#  'rahul',
#  'vivek',
#  'shafibul',
# ...

# %%
file.write('\n'.join(name_line))
# Out:
# 113224

# %%
with open ("name.txt","w")as fp:
   for line in name_line:
       fp.write(line+"\n")
